# %%
pip install openai
# Out:
# Requirement already satisfied: openai in ./venv/lib/python3.14/site-packages (2.7.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in ./venv/lib/python3.14/site-packages (from openai) (4.11.0)
# Requirement already satisfied: distro<2,>=1.7.0 in ./venv/lib/python3.14/site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in ./venv/lib/python3.14/site-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in ./venv/lib/python3.14/site-packages (from openai) (0.11.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in ./venv/lib/python3.14/site-packages (from openai) (2.12.4)
# Requirement already satisfied: sniffio in ./venv/lib/python3.14/site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in ./venv/lib/python3.14/site-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in ./venv/lib/python3.14/site-packages (from openai) (4.15.0)
# Requirement already satisfied: idna>=2.8 in ./venv/lib/python3.14/site-packages (from anyio<5,>=3.5.0->openai) (3.11)
# Requirement already satisfied: certifi in ./venv/lib/python3.14/site-packages (from httpx<1,>=0.23.0->openai) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in ./venv/lib/python3.14/site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in ./venv/lib/python3.14/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in ./venv/lib/python3.14/site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in ./venv/lib/python3.14/site-packages (from pydantic<3,>=1.9.0->openai) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in ./venv/lib/python3.14/site-packages (from pydantic<3,>=1.9.0->openai) (0.4.2)
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from fastapi import FastAPI
from pydantic import BaseModel
from openai import OpenAI
from dotenv import load_dotenv
import os
import json
from fastapi import UploadFile, File
import pathlib
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 3
#       1 from fastapi import FastAPI
#       2 from pydantic import BaseModel
# ----> 3 from openai import OpenAI
#       4 from dotenv import load_dotenv
#       5 import os
#
# File ~/Desktop/rpg_chatbot/venv/lib/python3.14/site-packages/openai/__init__.py:90
#      87 if not _t.TYPE_CHECKING:
#      88     from ._utils._resources_proxy import resources as resources
# ---> 90 from .lib import azure as _azure, pydantic_function_tool as pydantic_function_tool
#      91 from .version import VERSION as VERSION
#      92 from .lib.azure import AzureOpenAI as AzureOpenAI, AsyncAzureOpenAI as AsyncAzureOpenAI
#
# File ~/Desktop/rpg_chatbot/venv/lib/python3.14/site-packages/openai/lib/__init__.py:2
#       1 from ._tools import pydantic_function_tool as pydantic_function_tool
# ----> 2 from ._parsing import ResponseFormatT as ResponseFormatT
#
# File ~/Desktop/rpg_chatbot/venv/lib/python3.14/site-packages/openai/lib/_parsing/__init__.py:1
# ----> 1 from ._completions import (
#       2     ResponseFormatT as ResponseFormatT,
#       3     has_parseable_input,
#       4     has_parseable_input as has_parseable_input,
#       5     maybe_parse_content as maybe_parse_content,
#       6     validate_input_tools as validate_input_tools,
#       7     parse_chat_completion as parse_chat_completion,
#       8     get_input_tool_by_name as get_input_tool_by_name,
#       9     solve_response_format_t as solve_response_format_t,
#      10     parse_function_tool_arguments as parse_function_tool_arguments,
#      11     type_to_response_format_param as type_to_response_format_param,
#      12 )
#
# File <frozen importlib._bootstrap>:1371, in _find_and_load(name, import_)
#    1369     module = sys.modules.get(name, _NEEDS_LOADING)
#    1370     if module is _NEEDS_LOADING:
# -> 1371         return _find_and_load_unlocked(name, import_)
#    1373 # Optimization: only call _bootstrap._lock_unlock_module() if
#    1374 # module.__spec__._initializing is True.
#    1375 # NOTE: because of this, initializing must be set *before*
#    1376 # putting the new module in sys.modules.
#    1377 _lock_unlock_module(name)
#
# File <frozen importlib._bootstrap>:1342, in _find_and_load_unlocked(name, import_)
#    1340     parent_spec._uninitialized_submodules.append(child)
#    1341 try:
# -> 1342     module = _load_unlocked(spec)
#    1343 finally:
#    1344     if parent_spec:
#
# File <frozen importlib._bootstrap>:938, in _load_unlocked(spec)
#     935             raise ImportError('missing loader', name=spec.name)
#     936         # A namespace package so do nothing.
#     937     else:
# --> 938         spec.loader.exec_module(module)
#     939 except:
#     940     try:
#
# File <frozen importlib._bootstrap_external>:758, in _LoaderBasics.exec_module(self, module)
#     756 def exec_module(self, module):
#     757     """Execute the module."""
# --> 758     code = self.get_code(module.__name__)
#     759     if code is None:
#     760         raise ImportError(f'cannot load module {module.__name__!r} when '
#     761                           'get_code() returns None')
#
# File <frozen importlib._bootstrap_external>:854, in SourceLoader.get_code(self, fullname)
#     852 source_mtime = int(st['mtime'])
#     853 try:
# --> 854     data = self.get_data(bytecode_path)
#     855 except OSError:
#     856     pass
#
# File <frozen importlib._bootstrap_external>:954, in FileLoader.get_data(self, path)
#     952 if isinstance(self, (SourceLoader, ExtensionFileLoader)):
#     953     with _io.open_code(str(path)) as file:
# --> 954         return file.read()
#     955 else:
#     956     with _io.FileIO(path, 'r') as file:
#
# KeyboardInterrupt:

# %%
from dotenv import load_dotenv

# %%
load_dotenv()
client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 2
#       1 load_dotenv()
# ----> 2 openai.api_key = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))
#
# NameError: name 'OpenAI' is not defined

# %%
def text_to_speech(text: str, filename: str = "npc_voice.mp3"):
    speech_file_path = pathlib.Path(filename)
    with client.audio.speech.with_streaming_response.create(
        model="gpt-4o-mini-tts",  # text-to-speech model
        voice="alloy",            # choose: alloy, verse, coral, sage, etc.
        input=text
    ) as response:
        response.stream_to_file(speech_file_path)
    return str(speech_file_path)
